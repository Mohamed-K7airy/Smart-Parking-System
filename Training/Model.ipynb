# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.95 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 47.4/112.6 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="sd6c6nrbg6R7sZuN3Dmw")
project = rf.workspace("jeremy-w3v4a").project("parking-detection-jeremykevin")
version = project.version(10)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo train \
model=yolo11s.pt \
data="/content/parking-detection-jeremyKevin-10/data.yaml" \
epochs=100 \
imgsz=640 \
batch=-1 \
patience=30 \
cache=True
# Out:
# Ultralytics 8.4.95 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !yolo predict \
model='/content/runs/detect/train-3/weights/best.pt' \
source='/content/pexels-photo-15095771.avif' \
show_conf=False \
show_labels=True
# Out:
# Ultralytics 8.4.95 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,413,574 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/1 /content/pexels-photo-15095771.avif: 480x640 47 cars, 12 frees, 57.9ms
# Speed: 3.1ms preprocess, 57.9ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /content/runs/detect/predict-9
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
